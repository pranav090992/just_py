# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('CDF Final Data.csv')

# %%
df.head()
# Out:
#    SL No.        Date LOCATION                    NAME NATIONALITY PASSPORTNO  \
# 0       1  11/23/2021   INBOM4   FATTARO MAMBAI HOSPET         SYR  00419L002
# 1       2   9/26/2022   INMAA4   KAMALANADHAN  YAMNICK         FRA  02YI13692
# 2       3   1/10/2021   INMAA4        DJANY KHATIDJABY         FRA  06AB43223
# 3       4   2/19/2022   INBOM4  GARZALI ALMADALHASSANE         NER  07DC92027
# 4       5  11/11/2021   INBOM4           YOUSSOG BELLO         NER  07P698721
#
#    AMOUNT DECLARED CURRENCYNAME  Currency Value   \
# 0          22000.0          USD       22,000.00
# 1           9000.0          EUR        9,000.00
# 2          12000.0          EUR       12,000.00
# 3         200000.0          USD      200,000.00
# 4          20500.0          USD       20,500.00
#
#                               CDFNO Exchange Rate Currency Value INR  \
# 0    CDF/Offline/INBOM4/GF56/002915        74.43       1,637,460.00
# ...
